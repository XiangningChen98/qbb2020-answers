# %% [markdown]
# # Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load fpkms.csv

# %%
df_fpkms = pd.read_csv( "../../qbb2020/data/fpkms.csv", index_col="t_name" )
df_fpkms
# Out:
#             gene_name    male_10    male_11    male_12    male_13   male_14A  \
# t_name
# FBtr0114258   CR41571   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0346770   CG45784   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302440   CR12798   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0302347   CR40182  23.712564  11.967821  20.767498  13.566818  18.802116
# FBtr0346769   CG45783   0.000000   0.000000   0.000000   0.000000   0.000000
# ...               ...        ...        ...        ...        ...        ...
# FBtr0114187   CR40502   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0304147   CR40719   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114216   CR40679   2.011199   0.000000   7.994137   2.064200   3.141665
# FBtr0114222   CR40743   0.000000   0.000000   0.000000   0.000000   0.000000
# FBtr0114283   CR41619   0.000000   0.000000   0.000000   0.000000   0.000000
#
# ...

# %% [markdown]
# # Subset transcript¶

# %%
goi = "FBtr0331261"
df_sxl = df_fpkms.loc[goi,:]
df_sxl
# Out:
# gene_name         Sxl
# male_10             0
# male_11             0
# male_12             0
# male_13             0
# male_14A            0
# male_14B            0
# male_14C            0
# male_14D      2.11732
# female_10           0
# female_11           0
# female_12           0
# female_13           0
# female_14A    46.0339
# female_14B    30.6056
# female_14C    38.9564
# female_14D    124.908
# Name: FBtr0331261, dtype: object

# %% [markdown]
# ## Male subset

# %%
df_sxl_male=df_sxl[1:9]
df_sxl_male
# Out:
# male_10           0
# male_11           0
# male_12           0
# male_13           0
# male_14A          0
# male_14B          0
# male_14C          0
# male_14D    2.11732
# Name: FBtr0331261, dtype: object

# %% [markdown]
# ## Female subset

# %%
df_sxl_female=df_sxl[9:]
df_sxl_female
# Out:
# female_10           0
# female_11           0
# female_12           0
# female_13           0
# female_14A    46.0339
# female_14B    30.6056
# female_14C    38.9564
# female_14D    124.908
# Name: FBtr0331261, dtype: object

# %%
df_replicates = pd.read_csv( "../../qbb2020/data/replicates.csv" , index_col="t_name" )
df_replicates
# Out:
#               male_14A   male_14B   male_14C   male_14D  female_14A  \
# t_name
# FBtr0114258   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0346770   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0302440   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0302347  22.995892  38.139065  11.577139  20.456739   60.885391
# FBtr0346769   0.000000   0.000000   0.000000   0.000000    0.000000
# ...                ...        ...        ...        ...         ...
# FBtr0114187   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0304147   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0114216   1.459697   0.731757   2.716971  65.821503    2.207145
# FBtr0114222   0.000000   0.000000   0.000000   0.000000    0.000000
# FBtr0114283   0.000000   0.000000   0.000000   0.000000    0.000000
#
#              female_14B  female_14C  female_14D gene_name
# t_name
# FBtr0114258    0.000000    0.000000    0.000000   CR41571
# ...

# %%
df_sxl_rep = df_replicates.loc[goi,:]
df_sxl_rep
# Out:
# male_14A            0
# male_14B            0
# male_14C            0
# male_14D            0
# female_14A          0
# female_14B    79.1035
# female_14C    182.233
# female_14D    2.40947
# gene_name         Sxl
# Name: FBtr0331261, dtype: object

# %%
df_sxl_rep[0:4]
# Out:
# male_14A    0
# male_14B    0
# male_14C    0
# male_14D    0
# Name: FBtr0331261, dtype: object

# %%
df_sxl_rep[4:8]
# Out:
# female_14A          0
# female_14B    79.1035
# female_14C    182.233
# female_14D    2.40947
# Name: FBtr0331261, dtype: object

# %% [markdown]
# ## Add replication

# %%
fig,ax=plt.subplots()
x=["10","11","12","13","14A","14B","14C","14D"]
y1_male=[]
y1_female=[]
y2_male=[]
y2_female=[]
for i in range(len(x)):
    y1_male.append(np.log2(df_sxl_male[i]+1))
    y1_female.append(np.log2(df_sxl_female[i]+1))
plt.plot(x,y1_male,'.',label='male1',color='blue')
plt.plot(x,y1_female,'.',label='female1',color='red')

for i in range(4):
    y2_male.append(np.log2(df_sxl_rep[i]+1))
    y2_female.append(np.log2(df_sxl_rep[4+i]+1))
    

plt.plot(x[4:],y2_male,'.',color='darkblue',label='male2')
plt.plot(x[4:],y2_female,'.',color='darkred',label='female2')

plt.title('log2 time course of FBtr0331261')
plt.legend()
plt.ylabel('log2(fpkms)')
plt.xlabel('stage')
plt.show()
